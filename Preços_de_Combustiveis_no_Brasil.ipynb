# %% [markdown]
# <a href="https://colab.research.google.com/github/claudett4/Precos-de-Combustiveis-no-Brasil/blob/main/Pre%C3%A7os_de_Combustiveis_no_Brasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
np.loadtxt('combustiveis-brasil.csv', delimiter=',', usecols= np.arange(1,6,1),skiprows=1)

# %%
dado = np.loadtxt('combustiveis-brasil.csv', delimiter=',', usecols= np.arange(1,6,1),skiprows=1)

# %%
datas = dado [:,0]

# %%
preco_medio_gas = dado [:,2]

# %%
preco_2002 = preco_medio_gas [6:18]
preco_2003 = preco_medio_gas [18:30]
preco_2004 = preco_medio_gas [30:42]

# %%
preco_2018 = preco_medio_gas [198:210]
preco_2019 = preco_medio_gas [210:222]
preco_2020 = preco_medio_gas [222:234]

# %%
import matplotlib.pyplot as plt
plt.plot(np.arange(1,13,1), preco_2002)
plt.plot(np.arange(1,13,1), preco_2003)
plt.plot(np.arange(1,13,1), preco_2004)
plt.legend(['ano_2002','ano_2003','ano_2004'])

# %%
import matplotlib.pyplot as plt
plt.plot(np.arange(1,13,1), preco_2018)
plt.plot(np.arange(1,13,1), preco_2019)
plt.plot(np.arange(1,13,1), preco_2020)
plt.legend(['ano_2018','ano_2019','ano_2020'])
